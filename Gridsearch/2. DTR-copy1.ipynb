# %%
import pandas as pd
import numpy as ny
import matplotlib as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dep=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error','absolute_error','friedman_mse'], 'splitter':['best','random',], 'max_features':['auto','sqrt','log2'] }
grid=GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3, n_jobs=1)
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END criterion=squared_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_features=auto, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_features=auto, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_features=auto, splitter=random;, score=nan total time=   0.0s
# ...

# %%
re=grid.cv_results_
print("The R_score for best model{}:".format(grid.best_params_))
# Out:
# The R_score for best model{'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000000      0.000000         0.000000        0.000000
# 1        0.000000      0.000000         0.000000        0.000000
# 2        0.015620      0.000014         0.009374        0.007654
# 3        0.010396      0.005921         0.009093        0.003976
# 4        0.019745      0.004955         0.001017        0.002034
# 5        0.011945      0.003172         0.008947        0.005285
# 6        0.000000      0.000000         0.000000        0.000000
# 7        0.000000      0.000000         0.000000        0.000000
# 8        0.063790      0.009826         0.003941        0.006052
# 9        0.043499      0.005868         0.005861        0.005814
# 10       0.067519      0.007806         0.011188        0.006388
# 11       0.046717      0.006738         0.005258        0.005133
# 12       0.002626      0.005253         0.000000        0.000000
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 23
# BMI: 31
# Children: 3
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Predictions=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Predictions={}".format(Future_Predictions))
# Out:
# Future_Predictions=[36189.1017]
# C:\dell\envs\aiml\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
