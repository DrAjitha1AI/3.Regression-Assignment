# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dep=dataset[['charges']]

# %%
#remove train and testset split
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(indep, dep, test_size=1/3, random_state=0)

# %%
#remove standardisation
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
X_train

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
#model creation with Cross Validation and Grid Search
from sklearn.model_selection import GridSearchCV

param_grid={'criterion':['squared_error','absolute_error','friedman_mse'], 'max_features':['auto','sqrt','log2'], 'n_estimators':[10,100]}

grid=GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)

#fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# C:\dell\envs\aiml\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 30 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 26 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\dell\envs\aiml\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.81398636 0.83166685 0.81744294 0.83344681
#         nan        nan 0.81611362 0.83344821 0.81974853 0.83069053
#         nan        nan 0.81508902 0.83577949 0.81731544 0.83332719]
#   warnings.warn(
# C:\dell\envs\aiml\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
#print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_

print("The R_score value for best parameter{}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter{'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003013      0.003746         0.000000        0.000000
# 1        0.003129      0.003569         0.000000        0.000000
# 2        0.100647      0.009901         0.009448        0.002466
# 3        0.800283      0.023006         0.024727        0.006721
# 4        0.091879      0.009178         0.006834        0.001939
# 5        0.765819      0.016949         0.018366        0.001582
# 6        0.001329      0.002658         0.000000        0.000000
# 7        0.002917      0.003963         0.000000        0.000000
# 8        0.250705      0.013875         0.006135        0.004063
# 9        2.191241      0.051042         0.022257        0.002897
# 10       0.223914      0.007843         0.007627        0.003893
# 11       2.529364      0.440542         0.020077        0.006579
# 12       0.000000      0.000000         0.000000        0.000000
# 13       0.001601      0.003203         0.000000        0.000000
# 14       0.084387      0.009662         0.008055        0.004171
# 15       0.768905      0.015046         0.019103        0.002371
# 16       0.090872      0.010924         0.007445        0.005375
# 17       1.241099      0.140221         0.038210        0.003933
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               auto                 10
# 1    squared_error               auto                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6   absolute_error               auto                 10
# 7   absolute_error               auto                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
# 12    friedman_mse               auto                 10
# 13    friedman_mse               auto                100
# 14    friedman_mse               sqrt                 10
# 15    friedman_mse               sqrt                100
# 16    friedman_mse               log2                 10
# 17    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.827947
# 3   {'criterion': 'squared_error', 'max_features':...           0.853883
# 4   {'criterion': 'squared_error', 'max_features':...           0.843465
# 5   {'criterion': 'squared_error', 'max_features':...           0.855103
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.844171
# 9   {'criterion': 'absolute_error', 'max_features'...           0.860283
# 10  {'criterion': 'absolute_error', 'max_features'...           0.852115
# 11  {'criterion': 'absolute_error', 'max_features'...           0.854432
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.833811
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.861542
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.846731
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.855297
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.743637           0.843643           0.820583
# 3            0.780919           0.859096           0.827822
# 4            0.756244           0.835370           0.816758
# 5            0.783995           0.862541           0.827779
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.759439           0.840062           0.804960
# 9            0.780836           0.856198           0.823977
# 10           0.757054           0.846618           0.819058
# 11           0.775910           0.854271           0.825367
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.764641           0.845136           0.815122
# 15           0.782670           0.861884           0.827644
# 16           0.741013           0.857012           0.818451
# 17           0.778385           0.864412           0.826172
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               13
# 1                 NaN              NaN             NaN               13
# 2            0.834122         0.813986        0.035979               12
# 3            0.836615         0.831667        0.027787                5
# 4            0.835378         0.817443        0.031831                8
# 5            0.837817         0.833447        0.027612                3
# 6                 NaN              NaN             NaN               13
# 7                 NaN              NaN             NaN               13
# 8            0.831936         0.816114        0.031456               10
# 9            0.845947         0.833448        0.029160                2
# 10           0.823897         0.819749        0.033817                7
# 11           0.843474         0.830691        0.029368                6
# 12                NaN              NaN             NaN               13
# 13                NaN              NaN             NaN               13
# 14           0.816735         0.815089        0.027572               11
# 15           0.845158         0.835779        0.029394                1
# 16           0.823371         0.817315        0.040746                9
# 17           0.842371         0.833327        0.030334                4

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 32
# BMI: 21
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Predictions=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Predictions={}".format(Future_Predictions))
# Out:
# Future_Predictions=[7927.3855567]
# C:\dell\envs\aiml\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
