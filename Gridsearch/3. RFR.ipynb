# %%
import numpy as ny
import pandas as pd
import matplotlib as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dep=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test= train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV

param_grid={'criterion':['squared_error', 'absolute_error', 'friedman_mse'], 'max_features':['auto','sqrt','log2'], 'n_estimators':[10,100]}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)

grid.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# C:\dell\envs\aiml\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 30 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 22 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\dell\envs\aiml\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\dell\envs\aiml\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.77676259 0.80197302 0.78121575 0.79967308
#         nan        nan 0.77160058 0.80304821 0.76178598 0.80328088
#         nan        nan 0.78834193 0.80004746 0.78274962 0.80196822]
#   warnings.warn(
# C:\dell\envs\aiml\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

grid_predictions=grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_predictions)
print("The R_score value for best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter{'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}: 0.8736761510452942

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002611      0.003881         0.000000        0.000000
# 1        0.006033      0.004926         0.000000        0.000000
# 2        0.047690      0.003898         0.007631        0.002973
# 3        0.438643      0.009449         0.016426        0.003634
# 4        0.053836      0.006450         0.004530        0.003367
# 5        0.432489      0.012630         0.012881        0.002326
# 6        0.001330      0.001796         0.000000        0.000000
# 7        0.000468      0.000936         0.000000        0.000000
# 8        0.108140      0.004485         0.003125        0.001872
# 9        1.057582      0.018887         0.015853        0.004658
# 10       0.103184      0.003210         0.003511        0.003754
# 11       1.102582      0.031409         0.010763        0.003096
# 12       0.003484      0.002310         0.000000        0.000000
# 13       0.000814      0.000901         0.000000        0.000000
# 14       0.066826      0.015180         0.009445        0.005310
# 15       0.417617      0.016585         0.011648        0.002432
# 16       0.043697      0.004721         0.003620        0.003909
# 17       0.390814      0.018564         0.013239        0.001770
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               auto                 10
# 1    squared_error               auto                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6   absolute_error               auto                 10
# 7   absolute_error               auto                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
# 12    friedman_mse               auto                 10
# 13    friedman_mse               auto                100
# 14    friedman_mse               sqrt                 10
# 15    friedman_mse               sqrt                100
# 16    friedman_mse               log2                 10
# 17    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.787506
# 3   {'criterion': 'squared_error', 'max_features':...           0.811013
# 4   {'criterion': 'squared_error', 'max_features':...           0.770400
# 5   {'criterion': 'squared_error', 'max_features':...           0.805307
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.736034
# 9   {'criterion': 'absolute_error', 'max_features'...           0.805795
# 10  {'criterion': 'absolute_error', 'max_features'...           0.760923
# 11  {'criterion': 'absolute_error', 'max_features'...           0.803318
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.785908
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.807933
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.804779
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.809995
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.746683           0.819158           0.788727
# 3            0.774994           0.834160           0.831443
# 4            0.741731           0.829600           0.819517
# 5            0.772676           0.834099           0.831091
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.750556           0.808047           0.807495
# 9            0.774130           0.839620           0.834907
# 10           0.725560           0.807204           0.758229
# 11           0.780641           0.839194           0.832001
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.756233           0.817455           0.813040
# 15           0.771045           0.829171           0.828629
# 16           0.744441           0.809263           0.805606
# 17           0.770612           0.842291           0.829400
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               13
# 1                 NaN              NaN             NaN               13
# 2            0.741739         0.776763        0.028939               10
# 3            0.758256         0.801973        0.030415                3
# 4            0.744831         0.781216        0.036900                9
# 5            0.755192         0.799673        0.031341                6
# 6                 NaN              NaN             NaN               13
# 7                 NaN              NaN             NaN               13
# 8            0.755870         0.771601        0.030239               11
# 9            0.760789         0.803048        0.031566                2
# 10           0.757014         0.761786        0.026120               12
# 11           0.761250         0.803281        0.029644                1
# 12                NaN              NaN             NaN               13
# 13                NaN              NaN             NaN               13
# 14           0.769073         0.788342        0.023941                7
# 15           0.763461         0.800047        0.027953                5
# 16           0.749658         0.782750        0.029234                8
# 17           0.757542         0.801968        0.032863                4

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
Sex_male_input=int(input("Sex Male 0 or 1:"))
Smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 23
# BMI: 31
# Children: 1
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,Sex_male_input,Smoker_yes_input]])
print("Future_Prediction={}:".format(Future_Prediction))
# Out:
# Future_Prediction=[33572.34806705]:
# C:\dell\envs\aiml\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
