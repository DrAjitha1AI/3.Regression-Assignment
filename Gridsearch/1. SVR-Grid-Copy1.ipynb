# %%
#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
indep
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dep=dataset[['charges']]
dep
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#remove train and testset split

# %%
#revome StandardScaler

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf', 'sigmoid', 'linear'], 
             'C':[10,100,500,1000,2000,3000], 'gamma':['auto', 'scale']}

grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=3, n_jobs=-1)

#fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\dell\envs\aiml\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 500, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'sigmoid', 'linear']},
#              verbose=3)

# %%
#print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.095316      0.005170         0.053700        0.003892      10
# 1        0.063509      0.002251         0.013815        0.002460      10
# 2        0.086514      0.010581         0.010817        0.004431      10
# 3        0.082183      0.003120         0.046428        0.005301      10
# 4        0.100773      0.006854         0.024256        0.004922      10
# 5        0.083632      0.006306         0.007759        0.003921      10
# 6        0.096252      0.005007         0.049978        0.004844     100
# 7        0.058091      0.004959         0.012060        0.003997     100
# 8        0.191944      0.012362         0.008940        0.004107     100
# 9        0.089218      0.010783         0.050707        0.001241     100
# 10       0.100917      0.004773         0.018181        0.002679     100
# 11       0.190782      0.004539         0.008952        0.005165     100
# 12       0.121097      0.007079         0.052017        0.004207     500
# 13       0.058864      0.003552         0.009214        0.002110     500
# 14       0.488103      0.042315         0.010230        0.001100     500
# 15       0.087793      0.005542         0.050829        0.005429     500
# 16       0.105593      0.003557         0.020353        0.002734     500
# 17       0.480969      0.043794         0.007829        0.002606     500
# 18       0.131530      0.003771         0.053122        0.005085    1000
# 19       0.059159      0.003248         0.014665        0.006810    1000
# 20       0.791833      0.124137         0.010703        0.001992    1000
# 21       0.089411      0.004676         0.047942        0.004296    1000
# 22       0.106573      0.004233         0.021167        0.001390    1000
# 23       0.778580      0.111576         0.009451        0.002154    1000
# 24       0.199908      0.016992         0.052787        0.002830    2000
# 25       0.062607      0.005873         0.011771        0.004464    2000
# 26       1.374371      0.219800         0.011540        0.002613    2000
# 27       0.088223      0.003219         0.053229        0.004768    2000
# 28       0.113382      0.009141         0.022616        0.004362    2000
# 29       1.340606      0.219475         0.012582        0.004925    2000
# 30       0.230697      0.013821         0.049639        0.007380    3000
# 31       0.064599      0.005990         0.012469        0.002186    3000
# 32       2.373719      0.430570         0.012823        0.003644    3000
# 33       0.097815      0.009838         0.048789        0.004884    3000
# 34       0.104626      0.006502         0.020365        0.004849    3000
# 35       2.147708      0.312976         0.007371        0.005956    3000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto      sigmoid
# 2         auto       linear
# 3        scale          rbf
# 4        scale      sigmoid
# 5        scale       linear
# 6         auto          rbf
# 7         auto      sigmoid
# 8         auto       linear
# 9        scale          rbf
# 10       scale      sigmoid
# 11       scale       linear
# 12        auto          rbf
# 13        auto      sigmoid
# 14        auto       linear
# 15       scale          rbf
# 16       scale      sigmoid
# 17       scale       linear
# 18        auto          rbf
# 19        auto      sigmoid
# 20        auto       linear
# 21       scale          rbf
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto      sigmoid
# 26        auto       linear
# 27       scale          rbf
# 28       scale      sigmoid
# 29       scale       linear
# 30        auto          rbf
# 31        auto      sigmoid
# 32        auto       linear
# 33       scale          rbf
# 34       scale      sigmoid
# 35       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.113791
# 1     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 2      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}          -0.018943
# 3        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.110409
# 4    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.116743
# 5     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}          -0.018943
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}          -0.100012
# 7    {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.559313
# 9       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}          -0.160182
# 10  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.142455
# 11   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.559313
# 12       {'C': 500, 'gamma': 'auto', 'kernel': 'rbf'}          -0.086611
# 13   {'C': 500, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.115328
# 14    {'C': 500, 'gamma': 'auto', 'kernel': 'linear'}           0.632135
# 15      {'C': 500, 'gamma': 'scale', 'kernel': 'rbf'}          -0.160916
# 16  {'C': 500, 'gamma': 'scale', 'kernel': 'sigmoid'}          -0.590878
# 17   {'C': 500, 'gamma': 'scale', 'kernel': 'linear'}           0.632135
# 18      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}          -0